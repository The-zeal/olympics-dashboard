# %%
import sys
sys.path.append('..')

from src.db import load_table

df_dominance = load_table("analytics", "gold_decade_dominance")
df_gender = load_table("analytics", "gold_female_representation")
df_age = load_table("analytics", "gold_age_medal_distribution")
df_sport = load_table("analytics", "gold_sport_competitiveness")
df_specialization = load_table("analytics", "gold_country_sport_specialization")

print(df_dominance.head())
# Out:
# DB_USER: postgres
# DB_HOST: localhost
# DB_PORT: 5432
# DB_NAME: sql_capstone
# PASSWORD: @LemonDZeal2
# Connection URL: postgresql+psycopg2://postgres:%40LemonDZeal2@localhost:5432/sql_capstone
# DB_USER: postgres
# DB_HOST: localhost
# DB_PORT: 5432
# DB_NAME: sql_capstone
# PASSWORD: @LemonDZeal2
# Connection URL: postgresql+psycopg2://postgres:%40LemonDZeal2@localhost:5432/sql_capstone
# DB_USER: postgres
# DB_HOST: localhost
# DB_PORT: 5432
# DB_NAME: sql_capstone
# PASSWORD: @LemonDZeal2
# Connection URL: postgresql+psycopg2://postgres:%40LemonDZeal2@localhost:5432/sql_capstone
# DB_USER: postgres
# DB_HOST: localhost
# DB_PORT: 5432
# DB_NAME: sql_capstone
# PASSWORD: @LemonDZeal2
# Connection URL: postgresql+psycopg2://postgres:%40LemonDZeal2@localhost:5432/sql_capstone
# DB_USER: postgres
# DB_HOST: localhost
# DB_PORT: 5432
# DB_NAME: sql_capstone
# PASSWORD: @LemonDZeal2
# Connection URL: postgresql+psycopg2://postgres:%40LemonDZeal2@localhost:5432/sql_capstone
#    decade top_country  top_country_medals  decade_total_medals  \
# 0    1890         GRE                  48                143.0
# 1    1900         USA                 546               2379.0
# 2    1910         SWE                 190                941.0
# 3    1920         USA                 490               3093.0
# 4    1930         USA                 335               1764.0
#
#    dominance_percentage
# 0                 33.57
# 1                 22.95
# 2                 20.19
# 3                 15.84
# 4                 18.99
